# %%
from recommendation.task.data_preparation.ifood import SplitSessionDataset,AddShiftAndWeekDayToSessionDataset

# %%
split_task = SplitSessionDataset()

split_task.run()
# Out:
# ---------------------------------------------------------------------------
# ExternalProgramRunError                   Traceback (most recent call last)
# <ipython-input-4-57a0452eb5e4> in <module>
#       1 split_task = SplitSessionDataset()
#       2
# ----> 3 split_task.run()
#
# ~/anaconda3/envs/recommendation-system/lib/python3.6/site-packages/luigi/contrib/spark.py in run(self)
#     296             self._dump(fd)
#     297         try:
# --> 298             super(PySparkTask, self).run()
#     299         finally:
#     300             shutil.rmtree(self.run_path)
#
# ~/anaconda3/envs/recommendation-system/lib/python3.6/site-packages/luigi/contrib/external_program.py in run(self)
#     116                 raise ExternalProgramRunError(
#     117                     'Program failed with return code={}:'.format(proc.returncode),
# --> 118                     args, env=env, stdout=stdout, stderr=stderr)
#     119         finally:
#     120             tmp_stderr.close()
#
# ...
