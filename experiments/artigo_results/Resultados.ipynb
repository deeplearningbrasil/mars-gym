# %% [markdown]
# ## Análise de Resultados

# %%
import sys, os
import plotly.graph_objects as go
import numpy as np

sys.path.insert(0, "/media/workspace/DeepFood/deep-reco-gym/tools/eval_viz")
import pandas as pd
import argparse
import copy
import numpy as np
import os
import random
import json
from pandas.io.json import json_normalize
from app import fetch_iteraction_results_path, load_all_iteraction_metrics
from app import load_iteractions_params as load_iteractions_params2, PATH_EVAL_REINFORCEMENT
from plot import plot_line_iteraction, plot_exploration_arm, get_colors, confidence
import pandas as pd
import argparse
import copy
import numpy as np
import streamlit as st
import seaborn as sns
sns.set(style="darkgrid")
#sys.path.insert(0, os.path.dirname(__file__))
import matplotlib.pyplot as plt
from app import load_data_metrics, load_eval_params, filter_df, fetch_results_path

# %%
models_and_legend = {
  "____random_":           ["bandit_policy", "observation"],
  "____fixed_":            ["bandit_policy", "observation"],
  "____lin_ucb_":          ["bandit_policy", "bandit_policy_params.alpha", "full_refit", "val_split_type"],
  "____model_":            ["bandit_policy","full_refit", "val_split_type"],
  "____custom_lin_ucb_":   ["bandit_policy", "bandit_policy_params.alpha", "full_refit", "val_split_type"],
  "____epsilon_greedy_":   ["bandit_policy","bandit_policy_params.epsilon", "full_refit", "val_split_type"],
  "____softmax_":          ["bandit_policy","bandit_policy_params.logit_multiplier", "full_refit", "val_split_type"],
  "____lin_ts_":           ["bandit_policy","bandit_policy_params.v_sq", "full_refit", "val_split_type"],
  "____percentile_adapt_":       ["bandit_policy","bandit_policy_params.exploration_threshold", "full_refit", "val_split_type"],
  "____adaptive_":         ["bandit_policy","bandit_policy_params.exploration_threshold", "bandit_policy_params.decay_rate", "full_refit", "val_split_type"],  
  "____explore_then_exp_": ["bandit_policy","bandit_policy_params.explore_rounds", "bandit_policy_params.decay_rate", "full_refit", "val_split_type"],    
}

path = PATH_EVAL_REINFORCEMENT

# %%
def list_paths_per_model(input_path):
    models = []
    
    for model, legend in models_and_legend.items():
    #print(model)
    #print(legend)
        for root, dirs, files in os.walk(input_path):
            if '/results' in root and 'Interaction' in root:
                for d in dirs:
                    #print(os.path.join(root, d))
                    if model in d:
                        models.append(os.path.join(root, d))
    return models

def load_iteractions_params(iteractions):
  if len(iteractions) == 0:
    return pd.DataFrame()

  dfs = []

  for model in iteractions:

    file_path = os.path.join(model, 'params.json')
    data      = []

    #try:
    with open(file_path) as json_file:
        d = json.load(json_file)
        data.append(d)

        df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
      
    #except:
    #  df = pd.DataFrame()

    df['iteraction'] = model
    dfs.append(df)
  
  return pd.concat(dfs)


def load_data_iteractions_metrics(path, sample_size = 10000):
    random.seed(42)
    file      = os.path.join(path,'sim-datalog.csv')

    # Count the lines
    num_lines = sum(1 for l in open(file)) - 1

    # Sample size - in this case ~10%
    size = np.min([sample_size, num_lines])#int(num_lines / 10)

    # The row indices to skip - make sure 0 is not included to keep the header!
    skip_idx  = sorted(random.sample(range(1, num_lines), num_lines - size))
    idx       = list(set(list(range(num_lines))) - set(skip_idx))

    df        = pd.read_csv(file, skiprows=skip_idx)
    
    df        = pd.read_csv(file)#.reset_index()
    idx       = list(range(len(df)))

    df['idx'] = sorted(idx)
    df        = df.sort_values("idx")
    return df


def get_metrics_reward(bandits):
    data    = []
    for i, p in enumerate(bandits):
        df_metrics = load_data_iteractions_metrics(p)
        r_mean     = df_metrics.reward.mean()
        r_reward   = df_metrics.reward.sum()
        data.append((i, r_mean, r_reward))
    df_metrics = pd.DataFrame(data, columns=['idx', 'r_mean', 'r_reward']).set_index('idx')    
    return df_metrics

def group_metrics(df):
    df_g_metrics = df.groupby('bandit').agg({'r_mean': ['mean', 'std'], 'r_reward': ['mean', 'std', 'count'], 'model': 'first' })
    df_g_metrics.columns = df_g_metrics.columns.map(lambda x: '|'.join([str(i) for i in x]))
    return df_g_metrics    
    
result_paths = list_paths_per_model(path)
result_paths
# Out:
# ['output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____random_889dbe45b7',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_89ba505e70',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_b622749ddb',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f1090a11f4',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_333462cf34',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_b33b92b16c',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_9312eb5d15',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_204a4db06b',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587 (2)',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_25ff6b86de',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a017cf3979',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_7c0b605db4',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_4d2ab7f3c2',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_59d0e0e8fb',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_1263e7da17',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_424c3eac17',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_e9ad3cb0fc',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_c633a2cd69',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_634308651f',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_a40a66211c',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c',
#  'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_b764df6558']

# %%
fetch_results_path()
# Out:
# {'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_41a85c6354_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_41a85c6354_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_685813f236_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_685813f236_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_44b982ca0f_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_44b982ca0f_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_ff1d5cf108_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_ff1d5cf108_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_e69727a7bb_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_e69727a7bb_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_57160a4dda_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_57160a4dda_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_a5ddbb5e2f_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_a5ddbb5e2f_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_03cced1313_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_03cced1313_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_9cd9c22b20_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_9cd9c22b20_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e_1099f3558d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e_1099f3558d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_06b3543934_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_06b3543934_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_d0e4e74718_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_d0e4e74718_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_20cdc70f33_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_20cdc70f33_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_09a9da5d43_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_09a9da5d43_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_901e2a3162_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_901e2a3162_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_76c4b31835_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_76c4b31835_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_8c94e30d68_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_8c94e30d68_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_32092f9be3_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_32092f9be3_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_c95a5930e6_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_c95a5930e6_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_b42b7bf7ba_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_b42b7bf7ba_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950_c2087d2882_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950_c2087d2882_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_a1a87729b2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_a1a87729b2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_c3b8218842_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_c3b8218842_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e_7b2fed8ef5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e_7b2fed8ef5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_9c0e4d5c87_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_9c0e4d5c87_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_f003c97fb4_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_f003c97fb4_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_640bcbff1d_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_640bcbff1d_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_ef7ea3acf3_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_ef7ea3acf3_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_5f86891d8b_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_5f86891d8b_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_37999ee85c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_37999ee85c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_1744fd53cc_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_1744fd53cc_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_b4167e0c47_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_b4167e0c47_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_7fa4094ffa_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_7fa4094ffa_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_3b5fb7c567_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_3b5fb7c567_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_20d7784b68_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_20d7784b68_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d00837a6b6_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d00837a6b6_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_37372dc93f_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_37372dc93f_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_e660aaea02_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_e660aaea02_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_d31575c86c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_d31575c86c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_a42b64843c_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_a42b64843c_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_d50c8ee63d_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_d50c8ee63d_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_254cae0a91_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_254cae0a91_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_9f1734b993_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_9f1734b993_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_43d5853a51_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_43d5853a51_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_c5463103dd_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_c5463103dd_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'}

# %% [markdown]
# ## Filter Data

# %%
#city = "Rio de Janeiro, Brazil"
#city = "Como, Italy"
#city = "Chicago, USA"
#city = "New York, USA"
#city = 'Copenhagen, Denmark'
city='recsys'

df_params = load_iteractions_params(result_paths)
df_params = df_params[df_params['data_frames_preparation_extra_params.filter_city'] == city]
df_params.head()
# Out:
# /home/marlesson/anaconda3/envs/deep-reco-gym/lib/python3.6/site-packages/ipykernel_launcher.py:39: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#   activation_function balance_fields bandit_policy  \
# 0  selu                []             random
# 0  selu                []             fixed
# 0  selu                []             lin_ucb
# 0  selu                []             lin_ucb
# 0  selu                []             lin_ucb
#
#    bandit_policy_params.alpha  bandit_policy_params.arg  \
# 0 NaN                         NaN
# 0 NaN                          2.0
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
#
#    bandit_policy_params.decay_rate  bandit_policy_params.epsilon  \
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
#
#    bandit_policy_params.exploration_threshold  \
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
#
#    bandit_policy_params.explore_rounds  bandit_policy_params.logit_multiplier  \
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
#
#    ...  sampling_strategy  seed session_test_size  split_index test_size  \
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
#
#   test_split_type use_sampling_in_validation  val_size  val_split_type  \
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
#
#     weight_init
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
#
# [5 rows x 55 columns]

# %%
df_params
# Out:
#   activation_function balance_fields         bandit_policy  \
# 0  selu                []             random
# 0  selu                []             fixed
# 0  selu                []             lin_ucb
# 0  selu                []             lin_ucb
# 0  selu                []             lin_ucb
# 0  selu                []             model
# 0  selu                []             model
# 0  selu                []             model
# 0  selu                []             model
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             epsilon_greedy
# 0  selu                []             epsilon_greedy
# 0  selu                []             epsilon_greedy
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             lin_ts
# 0  selu                []             lin_ts
# 0  selu                []             percentile_adaptive
# 0  selu                []             percentile_adaptive
# 0  selu                []             adaptive
# 0  selu                []             adaptive
# 0  selu                []             explore_then_exploit
# 0  selu                []             explore_then_exploit
#
#    bandit_policy_params.alpha  bandit_policy_params.arg  \
# 0 NaN                         NaN
# 0 NaN                          2.0
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
#
#    bandit_policy_params.decay_rate  bandit_policy_params.epsilon  \
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                               0.1
# 0 NaN                               0.1
# 0 NaN                               0.1
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0  0.000097                        NaN
# 0  0.000097                        NaN
# 0  0.000187                        NaN
# 0  0.000187                        NaN
#
#    bandit_policy_params.exploration_threshold  \
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0  0.7
# 0  0.7
# 0  0.7
# 0  0.7
# 0 NaN
# 0 NaN
#
#    bandit_policy_params.explore_rounds  bandit_policy_params.logit_multiplier  \
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0  1000.0                              NaN
# 0  1000.0                              NaN
#
#    ...  sampling_strategy  seed session_test_size  split_index test_size  \
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               2     0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               5     0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               4     0.1               0            0.2
# 0  ...  none               1     0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               7     0.1               0            0.2
# 0  ...  none               3     0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               2     0.1               0            0.2
# 0  ...  none               2     0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               3     0.1               0            0.2
# 0  ...  none               1     0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
#
#   test_split_type use_sampling_in_validation  val_size  val_split_type  \
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
#
#     weight_init
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
#
# [37 rows x 55 columns]

# %%
list_bandits          = df_params.groupby(["bandit_policy", "observation"])['iteraction'].apply(list).reset_index()
list_bandits['name']  = list_bandits.bandit_policy.map(str) + ' ' + list_bandits.observation.map(str)
list_bandits['name']  = list_bandits['name'].apply(lambda x: x.replace("fixed ", "").replace(" ", ""))
list_bandits['model'] = list_bandits.iteraction.apply(lambda l: l[np.random.randint(0, len(l))])
list_bandits['model_list'] = list_bandits.iteraction
list_bandits
# Out:
#            bandit_policy   observation  \
# 0   adaptive
# 1   custom_lin_ucb
# 2   epsilon_greedy
# 3   explore_then_exploit
# 4   fixed                 Popular Item
# 5   lin_ts
# 6   lin_ucb
# 7   model
# 8   percentile_adaptive
# 9   random
# 10  softmax_explorer
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           iteraction  \
# 0   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c]
# 1   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_9312eb5d15, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_204a4db06b, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587 (2), output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_25ff6b86de, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a017cf3979, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_7c0b605db4, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_4d2ab7f3c2, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_59d0e0e8fb]
# 2   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_1263e7da17, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_424c3eac17]
# 3   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_b764df6558]
# 4   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_89ba505e70]
# 5   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_c633a2cd69, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_634308651f]
# 6   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_b622749ddb, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f1090a11f4, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9]
# 7   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_333462cf34, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_b33b92b16c, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf]
# 8   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_a40a66211c]
# 9   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____random_889dbe45b7]
# 10  [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_e9ad3cb0fc, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950]
#
#                     name  \
# 0   adaptive
# 1   custom_lin_ucb
# 2   epsilon_greedy
# 3   explore_then_exploit
# 4   PopularItem
# 5   lin_ts
# 6   lin_ucb
# 7   model
# 8   percentile_adaptive
# 9   random
# 10  softmax_explorer
#
#                                                                                                                              model  \
# 0   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c
# 1   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 2   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f
# 3   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c
# 4   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_89ba505e70
# 5   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_634308651f
# 6   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f1090a11f4
# 7   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf
# 8   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_a40a66211c
# 9   output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____random_889dbe45b7
# 10  output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           model_list
# 0   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c]
# 1   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_9312eb5d15, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_204a4db06b, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587 (2), output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_25ff6b86de, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a017cf3979, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_7c0b605db4, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_4d2ab7f3c2, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_59d0e0e8fb]
# 2   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_1263e7da17, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_424c3eac17]
# 3   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_b764df6558]
# 4   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_89ba505e70]
# 5   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_c633a2cd69, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_634308651f]
# 6   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_b622749ddb, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f1090a11f4, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9]
# 7   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_333462cf34, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_b33b92b16c, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf]
# 8   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_a40a66211c]
# 9   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____random_889dbe45b7]
# 10  [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_e9ad3cb0fc, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950]

# %%
df_params
# Out:
#   activation_function balance_fields         bandit_policy  \
# 0  selu                []             random
# 0  selu                []             fixed
# 0  selu                []             lin_ucb
# 0  selu                []             lin_ucb
# 0  selu                []             lin_ucb
# 0  selu                []             model
# 0  selu                []             model
# 0  selu                []             model
# 0  selu                []             model
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             custom_lin_ucb
# 0  selu                []             epsilon_greedy
# 0  selu                []             epsilon_greedy
# 0  selu                []             epsilon_greedy
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             softmax_explorer
# 0  selu                []             lin_ts
# 0  selu                []             lin_ts
# 0  selu                []             percentile_adaptive
# 0  selu                []             percentile_adaptive
# 0  selu                []             adaptive
# 0  selu                []             adaptive
# 0  selu                []             explore_then_exploit
# 0  selu                []             explore_then_exploit
#
#    bandit_policy_params.alpha  bandit_policy_params.arg  \
# 0 NaN                         NaN
# 0 NaN                          2.0
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0  0.00001                    NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
# 0 NaN                         NaN
#
#    bandit_policy_params.decay_rate  bandit_policy_params.epsilon  \
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                               0.1
# 0 NaN                               0.1
# 0 NaN                               0.1
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0  0.000097                        NaN
# 0  0.000097                        NaN
# 0  0.000187                        NaN
# 0  0.000187                        NaN
#
#    bandit_policy_params.exploration_threshold  \
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0  0.7
# 0  0.7
# 0  0.7
# 0  0.7
# 0 NaN
# 0 NaN
#
#    bandit_policy_params.explore_rounds  bandit_policy_params.logit_multiplier  \
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                   5.0
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0  1000.0                              NaN
# 0  1000.0                              NaN
#
#    ...  sampling_strategy  seed session_test_size  split_index test_size  \
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               2     0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               5     0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               4     0.1               0            0.2
# 0  ...  none               1     0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               7     0.1               0            0.2
# 0  ...  none               3     0.1               0            0.2
# 0  ...  none               12    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               2     0.1               0            0.2
# 0  ...  none               2     0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               3     0.1               0            0.2
# 0  ...  none               1     0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.2
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.2
# 0  ...  none               11    0.1               0            0.0
#
#   test_split_type use_sampling_in_validation  val_size  val_split_type  \
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
#
#     weight_init
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
#
# [37 rows x 55 columns]

# %% [markdown]
# ## Geral

# %%
reward_metrics = []

# %%
for i, row in list_bandits.iterrows():
    df_metrics = get_metrics_reward(row['iteraction'])
    df_metrics['bandit'] = row['name']
    df_metrics['model']  = row['model']

    df_g_metrics = group_metrics(df_metrics)
    reward_metrics.append(df_g_metrics)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-c75663b046fb> in <module>
#       1 for i, row in list_bandits.iterrows():
# ----> 2     df_metrics = get_metrics_reward(row['iteraction'])
#       3     df_metrics['bandit'] = row['name']
#       4     df_metrics['model']  = row['model']
#       5
#
# <ipython-input-11-d6ec10faf459> in get_metrics_reward(bandits)
#      67     data    = []
#      68     for i, p in enumerate(bandits):
# ---> 69         df_metrics = load_data_iteractions_metrics(p)
#      70         r_mean     = df_metrics.reward.mean()
#      71         r_reward   = df_metrics.reward.sum()
#
# <ipython-input-11-d6ec10faf459> in load_data_iteractions_metrics(path, sample_size)
#      45
#      46     # Count the lines
# ---> 47     num_lines = sum(1 for l in open(file)) - 1
#      48
#      49     # Sample size - in this case ~10%
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_1263e7da17/sim-datalog.csv'

# %%
df_all = pd.concat(reward_metrics)
df_all = df_all.reset_index().sort_values('bandit', ascending=False).set_index('bandit')
df_all

# %%
df_all[['r_reward|mean', 'r_reward|std']].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4b120868603e> in <module>
# ----> 1 df_all[['r_reward|mean', 'r_reward|std']].plot(kind='bar')
#
# NameError: name 'df_all' is not defined

# %%
df_all.to_csv("output/tmp/stats.csv")

# %% [markdown]
# ## Plot Test

# %%
list_bandits['name'] = list_bandits['name'].apply(lambda x: "popular_item" if x == "PopularItem" else x)
df_models = list_bandits.set_index('name')[['model_list']]
df_models
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             model_list
# name
# adaptive              [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c]
# custom_lin_ucb        [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_9312eb5d15, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_204a4db06b, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_df97ca1587 (2), output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_25ff6b86de, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a017cf3979, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_7c0b605db4, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_4d2ab7f3c2, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_59d0e0e8fb]
# epsilon_greedy        [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_1263e7da17, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_424c3eac17]
# explore_then_exploit  [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_b764df6558]
# popular_item          [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_89ba505e70]
# lin_ts                [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_c633a2cd69, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_634308651f]
# lin_ucb               [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_b622749ddb, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f1090a11f4, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9]
# model                 [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_333462cf34, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_b33b92b16c, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf]
# percentile_adaptive   [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_a40a66211c]
# random                [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____random_889dbe45b7]
# softmax_explorer      [output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_e9ad3cb0fc, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314, output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950]

# %%
df_models.index
# Out:
# Index(['adaptive', 'custom_lin_ucb', 'epsilon_greedy', 'explore_then_exploit',
#        'popular_item', 'lin_ts', 'lin_ucb', 'model', 'percentile_adaptive',
#        'random', 'softmax_explorer'],
#       dtype='object', name='name')

# %%
bandits           = ['adaptive', 'custom_lin_ucb', 'epsilon_greedy', 'explore_then_exploit',
                       'popular_item', 'lin_ts', 'lin_ucb', 'percentile_adaptive', 'random', 'softmax_explorer']

sample_size       = 15000
window_size       = 1000

# %%
def load_dataset(df_models, bandits, sample_size):
    data = []
    for bandit in bandits:
        input_iteraction  = [p.split("/")[-1] for p in df_models.loc[bandit].model_list]
        df_metrics        = load_all_iteraction_metrics(input_iteraction, sample_size)
        #params            = load_iteractions_params2(input_iteraction)
        
        
        df_metrics        = load_all_iteraction_metrics(input_iteraction, sample_size)
        df_metrics['_idx'] = 1
        df_metrics        = df_metrics.groupby(['iteraction', 'idx']).sum().fillna(0).groupby(level=0).cumsum().reset_index()
        df_metrics['mean_reward'] = (df_metrics.reward/df_metrics._idx).fillna(0)
        df_metrics['bandit']      = bandit
        
        data.append(df_metrics)
    return pd.concat(data, ignore_index=True)

df_group = load_dataset(df_models, bandits, sample_size)
df_group.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-590219287fd6> in <module>
#      16     return pd.concat(data, ignore_index=True)
#      17
# ---> 18 df_group = load_dataset(df_models, bandits, sample_size)
#      19 df_group.head()
#
# <ipython-input-22-590219287fd6> in load_dataset(df_models, bandits, sample_size)
#       3     for bandit in bandits:
#       4         input_iteraction  = [p.split("/")[-1] for p in df_models.loc[bandit].model_list]
# ----> 5         df_metrics        = load_all_iteraction_metrics(input_iteraction, sample_size)
#       6         #params            = load_iteractions_params2(input_iteraction)
#       7
#
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/app.py in load_all_iteraction_metrics(iteractions, sample_size)
#     218   for iteraction in iteractions:
#     219     #try:
# --> 220     metric = load_data_iteractions_metrics(iteraction, sample_size)
#     221     #except:
#     222     #  continue
#
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/app.py in load_data_iteractions_metrics(model, sample_size)
#     184
#     185   # Count the lines
# --> 186   num_lines = sum(1 for l in open(file)) - 1
#     187
#     188   # Sample size - in this case ~10%
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_1263e7da17/sim-datalog.csv'

# %%
# input_iteraction  = [p.split("/")[-1] for p in df_models.loc['adaptive'].model_list]

# df_metrics        = load_all_iteraction_metrics(input_iteraction, sample_size)
# df_metrics        = df_metrics.groupby(['iteraction', 'idx']).sum().fillna(0).groupby(level=0).cumsum().reset_index()
# df_metrics['mean_reward'] = (df_metrics.reward/df_metrics.idx).fillna(0)
# df_metrics

# %%
def plot_cum_reward(df, hue='bandit', legend=False, ylim=1):
    plt.figure()
    sns.set(style="darkgrid")

    # Plot the responses for different events and regions
    ax =  sns.lineplot(x="idx", y="mean_reward", hue=hue, legend=legend, data=df)
    ax.set_ylim(0,ylim)
    #ax.set(xlabel='Interactions', ylabel='Cumulative Mean Reward',fontsize=20)
    ax.tick_params(labelsize=11)
    ax.set_xlabel('Interactions',fontsize=15);
    ax.set_ylabel('Cumulative Mean Reward',fontsize=15);
    # Put the legend out of the figure
    if legend:
        plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=12)
    plt.savefig("output/tmp/iteraction.pdf",dpi=300, bbox_inches="tight")
    plt.show()

# %%
_df = df_group.groupby(['bandit', 'idx']).median().reset_index()
plot_cum_reward(_df, legend='full')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-982ea927ba32> in <module>
# ----> 1 _df = df_group.groupby(['bandit', 'idx']).median().reset_index()
#       2 plot_cum_reward(_df, legend='full')
#
# NameError: name 'df_group' is not defined

# %%
df_metrics
# df_group = load_dataset(df_models, bandits, 20000)
# plot_cum_reward(df_group, hue='bandit', legend='full')
# Out:
#        r_mean  r_reward          bandit  \
# idx
# 0    0.000000  0.0       custom_lin_ucb
# 1    0.281578  13995.0   custom_lin_ucb
# 2    0.000000  0.0       custom_lin_ucb
# 3    0.296780  18436.0   custom_lin_ucb
# 4    0.287493  14289.0   custom_lin_ucb
# 5    0.000000  0.0       custom_lin_ucb
# 6    0.000000  0.0       custom_lin_ucb
# 7    0.295412  18351.0   custom_lin_ucb
# 8    0.000000  0.0       custom_lin_ucb
# 9    1.000000  1.0       custom_lin_ucb
#
#                                                                                                                             model
# idx
# 0    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 1    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 2    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 3    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 4    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 5    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 6    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 7    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 8    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88
# 9    output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_a388c23b88

# %%
df_group
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-a5e738bb4ef7> in <module>
# ----> 1 df_group
#
# NameError: name 'df_group' is not defined

# %%
df_group = load_dataset(df_models, ['adaptive'], 1000)
df_group
plot_cum_reward(df_group, hue='iteraction', legend='full')

# %%
df_group.head()
# Out:
#                                                     iteraction  idx   user  \
# 0  TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c  0    2283
# 1  TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c  20   19001
# 2  TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c  132  40322
# 3  TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c  189  49354
# 4  TrivagoLogisticModelInteraction_selu____adaptive_508e556a0c  223  58386
#
#     item  reward  index_env  _idx  mean_reward    bandit
# 0  1194   0.0     479        1     0.0          adaptive
# 1  1543   0.0     3727       2     0.0          adaptive
# 2  4104   0.0     8344       3     0.0          adaptive
# 3  7171   0.0     13823      4     0.0          adaptive
# 4  13977  0.0     19749      5     0.0          adaptive

# %%
# sns.set(style="darkgrid")

# # Plot the responses for different events and regions
# ax =  sns.lineplot(x="idx", y="mean_reward", hue='bandit', legend=False, data=df_group)
# ax.set_ylim(0,0.35)
# ax.set(xlabel='Interactions', ylabel='Cumulative Mean Reward')

# # Put the legend out of the figure
# #plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# plt.savefig("output/tmp/iteraction.pdf",dpi=300)
# plt.show()

# %%
sns.set_style("whitegrid")

# Plot the responses for different events and regions
ax =  sns.lineplot(x="idx", y="mean_reward", hue='bandit', legend='full', data=df_group)
ax.set(xlabel='Interactions', ylabel='Cumulative Mean Reward')

# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("output/tmp/iteraction_2.png",dpi=300)

plt.show()

# %% [markdown]
# ## Plot

# %%
removed           = df_all.loc[['model ', 'FirstItem']]['model|first'].values

input_legend      = ['bandit_policy', 'observation']
input_iteraction  = [p.split("/")[-1] for p in df_all['model|first'] if p not in removed]
sample_size       = 10000
window_size       = 1000 

st.set_option("client.displayEnabled", False)

metrics           = load_all_iteraction_metrics(input_iteraction, sample_size)
params            = load_iteractions_params2(input_iteraction)

df_metrics_reward = metrics.groupby("iteraction").agg({'reward': ['mean', 'sum']}).reset_index().sort_values([('reward', 'sum')], ascending=False)

df  = metrics.merge(params, on=['iteraction'], how='left')\
            .merge(metrics.groupby("iteraction")\
                    .agg({'reward': 'mean'})\
                    .rename(columns={'reward': 'sum_reward'})\
                    .reset_index(), 
              on=['iteraction'], how='left')\
            .reset_index()\
            .sort_values(['sum_reward', 'idx'], ascending=[False, True])


df.to_pickle('output/tmp/iteraction_df.pkl')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-5699f906d8b2> in <module>
# ----> 1 removed           = df_all.loc[['model ', 'FirstItem']]['model|first'].values
#       2
#       3 input_legend      = ['bandit_policy', 'observation']
#       4 input_iteraction  = [p.split("/")[-1] for p in df_all['model|first'] if p not in removed]
#       5 sample_size       = 10000
#
# NameError: name 'df_all' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = df[df.bandit_policy != "model"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-6e1648e19a71> in <module>
# ----> 1 df = df[df.bandit_policy != "model"]
#
# NameError: name 'df' is not defined

# %%
k = 100
for i in range(k):
    
    for input_metrics in ['Cumulative Window Mean Reward', 'Cumulative Mean Reward']:

        #input_metrics = 'Cumulative Mean Reward'
        fig = plot_line_iteraction(df[df.idx < int((df.idx.max()/k) *i)], 'reward', 
                              title=input_metrics, 
                              legend=input_legend,
                              yrange=[0, 0.35], 
                              line_dict=get_colors(input_iteraction),
                              window=window_size,
                              cum=(input_metrics == 'Cumulative Reward'), 
                              mean=(input_metrics == 'Cumulative Mean Reward'),
                              roll=(input_metrics == 'Cumulative Window Mean Reward'))
        fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)
        fig.update_layout(font={'family': 'Courier New, monospace', 'size': 14}, height=550)
        fig.update_yaxes(range=[0, 0.5])
        fig.update_xaxes(range=[0, df.idx.max()])
        #fig.show(renderer="svg")
        fig.write_image("output/tmp/interactions/{}_{}.png".format(input_metrics, i)) #, width=1024, height=600, scale=2
        print(i,"... ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-37b567b6a143> in <module>
#       5
#       6         #input_metrics = 'Cumulative Mean Reward'
# ----> 7         fig = plot_line_iteraction(df[df.idx < int((df.idx.max()/k) *i)], 'reward',
#       8                               title=input_metrics,
#       9                               legend=input_legend,
#
# NameError: name 'df' is not defined

# %%
df = pd.read_pickle('output/tmp/iteraction_df.pkl')

# GERAL
for input_metrics in ['Cumulative Reward', 'Cumulative Window Mean Reward', 'Cumulative Mean Reward']:
    #input_metrics = 'Cumulative Mean Reward'
    fig = plot_line_iteraction(df, 'reward', 
                          title=input_metrics, 
                          legend=input_legend,
                          yrange=[0, 0.35], 
                          line_dict=get_colors(input_iteraction),
                          window=window_size,
                          cum=(input_metrics == 'Cumulative Reward'), 
                          mean=(input_metrics == 'Cumulative Mean Reward'),
                          roll=(input_metrics == 'Cumulative Window Mean Reward'))
    fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False, title="{} - dataset".format(city))
    fig.update_layout(font={'family': 'Courier New, monospace', 'size': 14}, height=550)
    fig.show(renderer="svg")

    fig.write_image("output/tmp/iteraction_{}.eps".format(input_metrics.replace(" ", "_"))) #, width=1024, height=600, scale=2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-416fabc0769e> in <module>
#       6     fig = plot_line_iteraction(df, 'reward',
#       7                           title=input_metrics,
# ----> 8                           legend=input_legend,
#       9                           yrange=[0, 0.35],
#      10                           line_dict=get_colors(input_iteraction),
#
# NameError: name 'input_legend' is not defined

# %% [markdown]
# ## Recsys Metrics

# %%
from app import load_data_metrics, load_eval_params, filter_df, fetch_results_path
from plot import plot_bar

RECSYS_METRICS = [
  "count",
  "mean_average_precision",
  "precision_at_1",
  "ndcg_at_5",
  "ndcg_at_10",
  "ndcg_at_15",
  "ndcg_at_20",
  "ndcg_at_50",
  "coverage_at_5",
  "coverage_at_10",
  "coverage_at_15",
  "coverage_at_20",
  "coverage_at_50",
  "personalization_at_5",
  "personalization_at_10",
  "personalization_at_15",
  "personalization_at_20",
  "personalization_at_50",
  "IPS",
  "CIPS",
  "SNIPS",
  "DirectEstimator",
  "DoublyRobust"]


input_metrics = [
  "precision_at_1",
  "ndcg_at_5",
  "coverage_at_5",
  "personalization_at_5",
  "IPS",
  "CIPS",
  "SNIPS",
  "DirectEstimator",
  "DoublyRobust"
]

# %%
input_models_eval = fetch_results_path().keys()
input_params      = []
input_models_eval
# Out:
# dict_keys([])

# %%
data_metrics       = load_data_metrics()
data_params        = load_eval_params()

df_metrics        = filter_df(data_metrics, input_models_eval, input_metrics, "")
df_eval_params    = filter_df(data_params, input_models_eval, input_params).transpose()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-a6d32d61a8af> in <module>
# ----> 1 data_metrics       = load_data_metrics()
#       2 data_params        = load_eval_params()
#       3
#       4 df_metrics        = filter_df(data_metrics, input_models_eval, input_metrics, "")
#       5 df_eval_params    = filter_df(data_params, input_models_eval, input_params).transpose()
#
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/app.py in load_data_metrics()
#     118 #@st.cache
#     119 def load_data_metrics():
# --> 120   return json2df(fetch_results_path(), 'metrics.json', 'path')
#     121
#     122 #@st.cache
#
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/util.py in json2df(paths, file, idx)
#      40   df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
#      41
# ---> 42   df = df.set_index(idx)
#      43
#      44   return df
#
# ~/anaconda3/envs/deep-reco-gym/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['path'] are in the columns"

# %%
confidence_metrics = data_metrics[[c for c in data_metrics.columns if "_C" in c]]
for c in input_metrics:
    c_column = c+"_C" 
    confidence_metrics[c_column] = data_metrics[c_column] if c_column in data_metrics else None
confidence_metrics = confidence_metrics[[c+"_C" for c in input_metrics]]

# %%
fig = plot_bar(df_metrics, confidence = confidence_metrics, title="Comparison of Recsys Metrics")

fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)
fig.update_layout(font={'family': 'Courier New, monospace', 'size': 14}, height=550)
fig.show(renderer="svg")

#fig.write_image("output/tmp/metrics/recsys_rank.eps")

# %%
confidence_metrics
# Out:
#                                                                                                                                       precision_at_1_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          None
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    None
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           None
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             None
#
#                                                                                                                                       ndcg_at_5_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          None
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    None
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           None
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             None
#
#                                                                                                                                       coverage_at_5_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          None
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    None
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           None
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             None
#
#                                                                                                                                       personalization_at_5_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          None
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    None
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           None
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             None
#
#                                                                                                                                           IPS_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.004920
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.006638
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.005363
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.005436
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.006761
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.002417
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.006873
#
#                                                                                                                                          CIPS_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.004920
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.006638
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.005363
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.005436
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.006761
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.002417
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.006873
#
#                                                                                                                                         SNIPS_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.000078
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.000116
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.000093
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.000090
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.000119
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.000043
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.000119
#
#                                                                                                                                       DirectEstimator_C  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          None
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    None
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  None
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           None
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             None
#
#                                                                                                                                        DoublyRobust_C
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.001470
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.001483
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.001446
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.001456
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.001490
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.000584
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.001491

# %%
df_metrics.round(3)
# Out:
#                                                                                                                                        precision_at_1  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.343
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.350
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.321
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.345
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.363
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.064
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.375
#
#                                                                                                                                        ndcg_at_5  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.446
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.453
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.445
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.461
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.460
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.174
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.466
#
#                                                                                                                                        coverage_at_5  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.441
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.405
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.432
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.379
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.377
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.420
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.401
#
#                                                                                                                                        personalization_at_5  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.492
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.485
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.486
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.482
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.482
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.487
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.482
#
#                                                                                                                                          IPS  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.026
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.027
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.024
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.026
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.028
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.004
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.028
#
#                                                                                                                                         CIPS  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.026
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.027
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.024
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.026
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.028
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.004
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.028
#
#                                                                                                                                        SNIPS  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.284
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.297
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.269
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.288
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.314
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.035
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.321
#
#                                                                                                                                        DirectEstimator  \
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.314
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.323
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.298
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.313
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.330
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.059
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.341
#
#                                                                                                                                        DoublyRobust
# path
# TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.315
# TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps          0.323
# TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps    0.298
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.314
# TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.331
# TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps           0.059
# TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps             0.342

# %%
df_metrics.round(3).to_csv("output/tmp/df_metrics_recsys.csv")

# %% [markdown]
# ## Fainess

# %%
from app import load_fairness_metrics, load_fairness_df
#from plot import plot_fairness_mistreatment
from app import load_data_metrics, load_eval_params, filter_df, fetch_results_path

TEMPLATE = 'plotly_white' #simple_white

def plot_fairness_mistreatment(df, metric, title=""):
    data = []

    data.append(go.Bar(y=df.index, x=df[metric], orientation='h',
                    error_x= dict(type='data', array=df[metric+"_C"]) if metric+"_C" in df.columns else {}  ,
                    marker={'color': list(range(len(df.index))), 
                            'colorscale': 'Tealgrn'})) #Plotly3

    fig = go.Figure(data=data)
    # Change the bar mode
    fig.update_layout(template=TEMPLATE, legend_orientation="h", 
                    xaxis_title=metric,
                    legend=dict(y=-0.2), title=title)
    #fig.update_traces(texttemplate='%{x:.2f}', textposition='outside')

    fig.update_layout(shapes=[
      dict(
        type= 'line',
        line=dict(
            width=1,
            dash="dot",
        ),        
        yref='paper', y0= 0, y1= 1,
        xref='x', x0= df[metric].mean(), x1= df[metric].mean()
      )
    ])

    st.plotly_chart(fig)

    return fig

# %% [markdown]
# ### current_filters_sort_by_price

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'
input_features    = 'current_filters_sort_by_price'
input_metrics     = 'true_positive_rate'

# %%
fetch_results_path()
# Out:
# {'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_41a85c6354_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_41a85c6354_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_685813f236_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_685813f236_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_44b982ca0f_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_44b982ca0f_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_4f5ce14ec6_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_ff1d5cf108_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_ff1d5cf108_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_7a6a314950_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_e69727a7bb_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_e69727a7bb_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_57160a4dda_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_57160a4dda_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_a5ddbb5e2f_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_a5ddbb5e2f_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_03cced1313_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_03cced1313_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_9cd9c22b20_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_9cd9c22b20_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e_1099f3558d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_6c6a3d810e_1099f3558d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_06b3543934_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_06b3543934_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_d0e4e74718_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_d0e4e74718_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_20cdc70f33_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_20cdc70f33_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_09a9da5d43_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_09a9da5d43_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_901e2a3162_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_901e2a3162_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_76c4b31835_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_76c4b31835_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_8c94e30d68_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_8c94e30d68_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_32092f9be3_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_32092f9be3_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_c95a5930e6_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_c95a5930e6_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d3e27d0bd5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_b42b7bf7ba_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_b42b7bf7ba_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950_c2087d2882_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_4342047950_c2087d2882_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_a1a87729b2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_a1a87729b2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_c3b8218842_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_c3b8218842_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e_7b2fed8ef5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_7780e4792e_7b2fed8ef5_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_9c0e4d5c87_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_9c0e4d5c87_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_f003c97fb4_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_f003c97fb4_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_640bcbff1d_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_640bcbff1d_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_ef7ea3acf3_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_ef7ea3acf3_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d05ce0b44c_20dd8241a2_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_5f86891d8b_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_5f86891d8b_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_37999ee85c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_37999ee85c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_1744fd53cc_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_9199322462_1744fd53cc_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_b4167e0c47_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_b4167e0c47_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_7fa4094ffa_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_7fa4094ffa_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_3b5fb7c567_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_3b5fb7c567_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_20d7784b68_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_20d7784b68_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d00837a6b6_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_014e22dd2f_d00837a6b6_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_37372dc93f_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_37372dc93f_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_e660aaea02_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_e660aaea02_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_4e140711f8_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_d31575c86c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_d31575c86c_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_a42b64843c_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_a42b64843c_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_d50c8ee63d_ps_per_pos_item_idx': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f9bf3a6cc9_d50c8ee63d_ps_per_pos_item_idx',
#  'TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_254cae0a91_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_dbbe2d18bf_254cae0a91_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_9f1734b993_ps_per_item_given_pos': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_0436f14db3_9f1734b993_ps_per_item_given_pos',
#  'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_43d5853a51_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_43d5853a51_ps_per_logistic_regression_of_pos_item_idx_and_item_ps',
#  'TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_c5463103dd_ps_per_logistic_regression_of_pos_item_idx_and_item': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____adaptive_9c821122a9_c5463103dd_ps_per_logistic_regression_of_pos_item_idx_and_item',
#  'TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps': 'output/evaluation/TrivagoLogisticModelInteractionEvaluate/results/TrivagoLogisticModelInteraction_selu____model_828c2e71ff_9d05d76c75_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'}

# %%
def plot_fairness_metrics(input_models_eval, input_features, input_metrics, sub_map = None):
    df_all_metrics    = load_fairness_metrics().loc[input_models_eval]
    df_instances      = load_fairness_df().loc[input_models_eval]
    df_all_metric_filter = df_all_metrics[df_all_metrics.sub_key.isin([input_features])]

    columns         = list(np.unique(['sub_key', 'sub', 'feature', 'total_class', 'total_individuals'] + [input_metrics]))
    if input_metrics+"_C" in df_all_metrics.columns:
        columns.append(input_metrics+"_C")

    df_metrics      = filter_df(df_all_metrics, input_models_eval, columns, 'sub')

    df_metrics      = df_metrics[df_metrics.sub_key.isin([input_features])]
    if sub_map != None:
        df_metrics['sub'] = df_metrics['sub'].map(sub_map)
    
    df_metrics      = df_metrics.sort_values("feature").set_index("sub")
    df_metrics      = df_metrics.sort_values(input_metrics)
    df_metrics
    
    fig = plot_fairness_mistreatment(df_metrics, input_metrics, title="")
    #title="Disparate Mistreatment: "+input_features
    
    fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False, yaxis_title=input_features)
    fig.update_layout(font={'family': 'Courier New, monospace', 'size': 17}, height=550)

    
    df_total     = df_metrics[['total_class', 'total_individuals']]
    df_total_sum = df_total.sum(numeric_only=True)
    df_percent   = df_total/df_total_sum
    df_total     = df_total.apply(lambda row: ["{} ({:.2f} %)".format(i, p*100) for i,p in zip(row, df_percent[row.name])])
    df_total.loc['total'] = df_total_sum
    df_total.head(10)    
    
    return fig, df_metrics, df_total

# %%
fig, df_metrics, df_total = plot_fairness_metrics(input_models_eval, input_features, input_metrics,
                                                 sub_map = {'1.0': 'True', '0.0': 'False'})

#fig.update_layout(scene = dict(xaxis = dict(tickfont=dict(size = 5, color='green'))))

# %%
fig.show(renderer="svg")



fig.write_image("output/tmp/metrics/recsys_fairnes_{}.eps".format(input_features))

# %%
df_metrics.head()
# Out:
#                                  feature                        sub_key  \
# sub
# True   current_filters_sort_by_price.1.0  current_filters_sort_by_price
# False  current_filters_sort_by_price.0.0  current_filters_sort_by_price
#
#        total_class  total_individuals  true_positive_rate  \
# sub
# True   1018         1303               0.218856
# False  3013         11115              0.313278
#
#        true_positive_rate_C
# sub
# True   0.026016
# False  0.013276

# %%
df_total.head()
# Out:
#           total_class total_individuals
# sub
# True   1018 (25.25 %)  1303 (10.49 %)
# False  3013 (74.75 %)  11115 (89.51 %)
# total  4031            12418

# %% [markdown]
# ### current_filters_sort_by_price

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'
input_features    = 'city_idx'
input_metrics     = 'true_positive_rate'

# %%
input_models_eval
# Out:
# 'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'

# %%
# sub_map = {'0': "Boston, USA",
#             '1': "Como, Italy",
#             '2': "Chicago, USA",
#             '3': "Lausanne, Switzerland",
#             '4': "Dublin, Ireland",
#             '5': "Rio de Janeiro, Brazil",
#             '6': "Barcelona, Spain",
#             '7': "Copenhagen, Denmark",
#             '8': "Vienna, Austria",
#             '9': "New York, USA",
#             '10': "Hong Kong, Hong Kong",
#             '11': "Vancouver, Canada"}

sub_map = {'0': "Boston",
            '1': "Como",
            '2': "Chicago",
            '3': "Lausanne",
            '4': "Dublin",
            '5': "Rio de Janeiro",
            '6': "Barcelona",
            '7': "Copenhagen",
            '8': "Vienna",
            '9': "New York",
            '10': "Hong Kong",
            '11': "Vancouver"}


fig, df_metrics, df_total = plot_fairness_metrics(input_models_eval, input_features, input_metrics,
                                                 sub_map = sub_map)
# Out:
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/util.py:21: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
# Set custom x-axis labels
fig.update_xaxes(nticks=4)

fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False, yaxis_title="City")
fig.update_layout(font={'family': 'Courier New, monospace', 'size': 20}, height=600)



fig.show(renderer="svg")
fig.write_image("output/tmp/metrics/paper/recsys_fairnes_{}.eps".format(input_features))

# %%
df_metrics.head(50)
# Out:
#                             feature   sub_key  total_class  total_individuals  \
# sub
# Como, Italy             city_idx.1   city_idx  30           30
# Dublin, Ireland         city_idx.4   city_idx  263          1035
# Vienna, Austria         city_idx.8   city_idx  392          1282
# Copenhagen, Denmark     city_idx.7   city_idx  125          572
# Barcelona, Spain        city_idx.6   city_idx  639          1652
# Rio de Janeiro, Brazil  city_idx.5   city_idx  567          2114
# Chicago, USA            city_idx.2   city_idx  152          375
# Boston, USA             city_idx.0   city_idx  109          198
# Lausanne, Switzerland   city_idx.3   city_idx  20           21
# Hong Kong, Hong Kong    city_idx.10  city_idx  398          1264
# New York, USA           city_idx.9   city_idx  642          3661
# Vancouver, Canada       city_idx.11  city_idx  83           214
#
#                         true_positive_rate  true_positive_rate_C
# sub
# Como, Italy             0.210526            0.185211
# Dublin, Ireland         0.238311            0.039911
# Vienna, Austria         0.279375            0.036585
# Copenhagen, Denmark     0.282810            0.058084
# Barcelona, Spain        0.284694            0.029722
# Rio de Janeiro, Brazil  0.289564            0.031434
# Chicago, USA            0.296978            0.063965
# Boston, USA             0.297377            0.080639
# Lausanne, Switzerland   0.313725            0.220319
# Hong Kong, Hong Kong    0.332064            0.039304
# New York, USA           0.332924            0.026229
# Vancouver, Canada       0.334243            0.090050

# %%
df_total.head()
# Out:
#                        total_class total_individuals
# sub
# Como, Italy          30 (0.88 %)    30 (0.24 %)
# Dublin, Ireland      263 (7.69 %)   1035 (8.33 %)
# Vienna, Austria      392 (11.46 %)  1282 (10.32 %)
# Copenhagen, Denmark  125 (3.65 %)   572 (4.61 %)
# Barcelona, Spain     639 (18.68 %)  1652 (13.30 %)

# %% [markdown]
# ### acessible hotel/park

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_43d5853a51_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'
input_features    = 'accessible hotel'
input_metrics     = 'true_positive_rate'

# %%
fig, df_metrics, df_total = plot_fairness_metrics(input_models_eval, input_features, input_metrics,
                                                 sub_map = None)
fig.show(renderer="svg")
# Out:
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/util.py:21: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
fig, df_metrics, df_total = plot_fairness_metrics(input_models_eval, 'accessible parking', input_metrics,
                                                 sub_map = None)
fig.show(renderer="svg")

# %%
input_features
sub_map = None

# %%
import plotly.express as px
print(px.colors.sequential.Tealgrn)
# Out:
# ['rgb(176, 242, 188)', 'rgb(137, 232, 172)', 'rgb(103, 219, 165)', 'rgb(76, 200, 163)', 'rgb(56, 178, 163)', 'rgb(44, 152, 160)', 'rgb(37, 125, 152)']

# %%
metrics = []


def plot_fairness_mistreatment(df, metric, title=""):
    data = []

    data.append(go.Bar(y=df.index, x=df[metric], orientation='h',
                    error_x= dict(type='data', array=df[metric+"_C"]) if metric+"_C" in df.columns else {}  ,
                    marker={'color': [px.colors.sequential.Tealgrn[i] for i in df.color]})) #Plotly3

    fig = go.Figure(data=data)
    # Change the bar mode
    fig.update_layout(template=TEMPLATE, legend_orientation="h", 
                    xaxis_title=metric,
                    legend=dict(y=-0.2), title=title)
    #fig.update_traces(texttemplate='%{x:.2f}', textposition='outside')

    fig.update_layout(shapes=[
      dict(
        type= 'line',
        line=dict(
            width=1,
            dash="dot",
        ),        
        yref='paper', y0= 0, y1= 1,
        xref='x', x0= df[metric].mean(), x1= df[metric].mean()
      )
    ])

    st.plotly_chart(fig)

    return fig

for input_features in ['accessible parking', 'accessible hotel']:
    df_all_metrics    = load_fairness_metrics().loc[input_models_eval]
    df_instances      = load_fairness_df().loc[input_models_eval]
    df_all_metric_filter = df_all_metrics[df_all_metrics.sub_key.isin([input_features])]

    columns         = list(np.unique(['sub_key', 'sub', 'feature', 'total_class', 'total_individuals'] + [input_metrics]))
    if input_metrics+"_C" in df_all_metrics.columns:
        columns.append(input_metrics+"_C")

    df_metrics      = filter_df(df_all_metrics, input_models_eval, columns, 'sub')

    df_metrics      = df_metrics[df_metrics.sub_key.isin([input_features])]
    if sub_map != None:
        df_metrics['sub'] = df_metrics['sub'].map(sub_map)

    df_metrics      = df_metrics.sort_values("feature").set_index("sub")
    df_metrics      = df_metrics.sort_values(input_metrics)
    metrics.append(df_metrics)

metrics = pd.concat(metrics)
metrics
# Out:
#                   feature             sub_key  total_class  total_individuals  \
# sub
# 1    accessible parking.1  accessible parking  1127         2546
# 0    accessible parking.0  accessible parking  3193         9872
# 1    accessible hotel.1    accessible hotel    1376         3716
# 0    accessible hotel.0    accessible hotel    3133         8702
#
#      true_positive_rate  true_positive_rate_C
# sub
# 1    0.211680            0.022268
# 0    0.289314            0.013621
# 1    0.241163            0.020246
# 0    0.281424            0.014234

# %%
metrics.reset_index()
metrics['sub'] = ['parking<br>True', 'parking<br>False', 'hotel<br>True', 'hotel<br>False']
metrics['color'] = [2,2, 5,5]
metrics = metrics.set_index('sub')
metrics
# Out:
#                                feature             sub_key  total_class  \
# sub
# parking<br>True   accessible parking.1  accessible parking  1127
# parking<br>False  accessible parking.0  accessible parking  3193
# hotel<br>True     accessible hotel.1    accessible hotel    1376
# hotel<br>False    accessible hotel.0    accessible hotel    3133
#
#                   total_individuals  true_positive_rate  true_positive_rate_C  \
# sub
# parking<br>True   2546               0.211680            0.022268
# parking<br>False  9872               0.289314            0.013621
# hotel<br>True     3716               0.241163            0.020246
# hotel<br>False    8702               0.281424            0.014234
#
#                   color
# sub
# parking<br>True   2
# parking<br>False  2
# hotel<br>True     5
# hotel<br>False    5

# %%
fig = plot_fairness_mistreatment(metrics, input_metrics, title="")

fig.update_layout(shapes=[
  dict(
    type= 'line',
    line=dict(
        width=1,
        dash="dot",
    ),        
    xref='paper', x0= 0, x1= 1,
    yref='y',     y0= 1.5, y1= 1.5
  )
])

# Set custom x-axis labels
fig.update_xaxes(nticks=4)

fig.update_layout(yaxis={'categoryorder':'array', 'categoryarray':['parking<br>False', 'parking<br>True', 'hotel<br>False', 'hotel<br>True']})
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False, yaxis_title="Accessible")
fig.update_layout(font={'family': 'Courier New, monospace', 'size': 22}, height=550)

fig.write_image("output/tmp/metrics/paper/recsys_fairnes_{}.eps".format("accessible"))    
fig.show(renderer="svg")

# %% [markdown]
# ## Business hotel

# %%
metrics = []
for input_features in ['hotel', 'house / apartment']:
    df_all_metrics    = load_fairness_metrics().loc[input_models_eval]
    df_instances      = load_fairness_df().loc[input_models_eval]
    df_all_metric_filter = df_all_metrics[df_all_metrics.sub_key.isin([input_features])]

    columns         = list(np.unique(['sub_key', 'sub', 'feature', 'total_class', 'total_individuals'] + [input_metrics]))
    if input_metrics+"_C" in df_all_metrics.columns:
        columns.append(input_metrics+"_C")

    df_metrics      = filter_df(df_all_metrics, input_models_eval, columns, 'sub')

    df_metrics      = df_metrics[df_metrics.sub_key.isin([input_features])]
    if sub_map != None:
        df_metrics['sub'] = df_metrics['sub'].map(sub_map)

    df_metrics      = df_metrics.sort_values("feature").set_index("sub")
    df_metrics      = df_metrics.sort_values(input_metrics)
    metrics.append(df_metrics)

metrics = pd.concat(metrics).reset_index().sort_values(['sub_key', 'sub'])
metrics
# Out:
#   sub              feature            sub_key  total_class  total_individuals  \
# 0  0   hotel.0              hotel              1595         2126
# 1  1   hotel.1              hotel              2614         10292
# 3  0   house / apartment.0  house / apartment  3006         11541
# 2  1   house / apartment.1  house / apartment  854          877
#
#    true_positive_rate  true_positive_rate_C
# 0  0.209243            0.021453
# 1  0.291112            0.013488
# 3  0.306631            0.013065
# 2  0.139288            0.026247

# %%
#metrics.reset_index().sort_values('sub_key')
metrics['color'] = [5,5, 2,2]
metrics['sub']   = ['hotel<br>False', 'hotel<br>True', 'house/apart<br>False', 'house/apart<br>True']
metrics = metrics.set_index('sub')
metrics
# Out:
#                                   feature            sub_key  total_class  \
# sub
# hotel<br>False        hotel.0              hotel              1595
# hotel<br>True         hotel.1              hotel              2614
# house/apart<br>False  house / apartment.0  house / apartment  3006
# house/apart<br>True   house / apartment.1  house / apartment  854
#
#                       total_individuals  true_positive_rate  \
# sub
# hotel<br>False        2126               0.209243
# hotel<br>True         10292              0.291112
# house/apart<br>False  11541              0.306631
# house/apart<br>True   877                0.139288
#
#                       true_positive_rate_C  color
# sub
# hotel<br>False        0.021453              5
# hotel<br>True         0.013488              5
# house/apart<br>False  0.013065              2
# house/apart<br>True   0.026247              2

# %%
fig = plot_fairness_mistreatment(metrics, input_metrics, title="")

fig.update_layout(shapes=[
  dict(
    type= 'line',
    line=dict(
        width=1,
        dash="dot",
    ),        
    xref='paper', x0= 0, x1= 1,
    yref='y',     y0= 1.5, y1= 1.5
  )
])

# Set custom x-axis labels
fig.update_xaxes(nticks=4)

fig.update_layout(yaxis={'categoryorder':'array', 'categoryarray':['house/apart<br>False', 'house/apart<br>True', 'hotel<br>False', 'hotel<br>True']})
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False, yaxis_title="Business")
fig.update_layout(font={'family': 'Courier New, monospace', 'size': 22}, height=550)



fig.write_image("output/tmp/metrics/paper/recsys_fairnes_{}.eps".format("business"))    
fig.show(renderer="svg")

# %% [markdown]
# ### Childcare

# %%
metrics = []
for input_features in ['childcare', 'family friendly']:
    df_all_metrics    = load_fairness_metrics().loc[input_models_eval]
    df_instances      = load_fairness_df().loc[input_models_eval]
    df_all_metric_filter = df_all_metrics[df_all_metrics.sub_key.isin([input_features])]

    columns         = list(np.unique(['sub_key', 'sub', 'feature', 'total_class', 'total_individuals'] + [input_metrics]))
    if input_metrics+"_C" in df_all_metrics.columns:
        columns.append(input_metrics+"_C")

    df_metrics      = filter_df(df_all_metrics, input_models_eval, columns, 'sub')

    df_metrics      = df_metrics[df_metrics.sub_key.isin([input_features])]
    if sub_map != None:
        df_metrics['sub'] = df_metrics['sub'].map(sub_map)

    df_metrics      = df_metrics.sort_values("feature").set_index("sub")
    df_metrics      = df_metrics.sort_values(input_metrics)
    metrics.append(df_metrics)

metrics = pd.concat(metrics)
metrics
# Out:
#                feature          sub_key  total_class  total_individuals  \
# sub
# 1    childcare.1        childcare        1027         2802
# 0    childcare.0        childcare        3222         9616
# 0    family friendly.0  family friendly  1942         2753
# 1    family friendly.1  family friendly  2446         9665
#
#      true_positive_rate  true_positive_rate_C
# sub
# 1    0.222654            0.022938
# 0    0.288659            0.013728
# 0    0.229201            0.019934
# 1    0.285930            0.014014

# %%
metrics.reset_index()
metrics['sub'] = ['childcare<br>True', 'childcare<br>False', 'family friendly<br>True', 'family friendly<br>False']
metrics['color'] = [2,2, 5,5]
metrics = metrics.set_index('sub')
metrics
# Out:
#                                     feature          sub_key  total_class  \
# sub
# childcare<br>True         childcare.1        childcare        1027
# childcare<br>False        childcare.0        childcare        3222
# family friendly<br>True   family friendly.0  family friendly  1942
# family friendly<br>False  family friendly.1  family friendly  2446
#
#                           total_individuals  true_positive_rate  \
# sub
# childcare<br>True         2802               0.222654
# childcare<br>False        9616               0.288659
# family friendly<br>True   2753               0.229201
# family friendly<br>False  9665               0.285930
#
#                           true_positive_rate_C  color
# sub
# childcare<br>True         0.022938              2
# childcare<br>False        0.013728              2
# family friendly<br>True   0.019934              5
# family friendly<br>False  0.014014              5

# %%
fig = plot_fairness_mistreatment(metrics, input_metrics, title="")



fig.update_layout(shapes=[
  dict(
    type= 'line',
    line=dict(
        width=1,
        dash="dot",
    ),        
    xref='paper', x0= 0, x1= 1,
    yref='y',     y0= 1.5, y1= 1.5
  )
])

# Set custom x-axis labels
fig.update_xaxes(nticks=4)

fig.update_layout(yaxis={'categoryorder':'array', 'categoryarray':['childcare<br>False', 'childcare<br>True', 'family friendly<br>False', 'family friendly<br>True']})
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False, yaxis_title="Business")
fig.update_layout(font={'family': 'Courier New, monospace', 'size': 22}, height=550)




fig.write_image("output/tmp/metrics/paper/recsys_fairnes_{}.eps".format("businesscare"))    
fig.show(renderer="svg")

# %% [markdown]
# ### popularity_BIN

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'
input_features    = 'price_BIN'
input_metrics     = 'true_positive_rate'

# %%
sub_map = {"0.0": "1º Quartil", "1.0": "2º Quartil", "2.0": "3º Quartil", "3.0": "4º Quartil"}



fig, df_metrics, df_total = plot_fairness_metrics(input_models_eval, input_features, input_metrics,
                                                 sub_map = sub_map)

# %%
fig.show(renderer="svg")
fig.write_image("output/tmp/metrics/recsys_fairnes_{}.eps".format(input_features))

# %%
df_metrics.head(50)
# Out:
#                   feature    sub_key  total_class  total_individuals  \
# sub
# 1º Quartil  price_BIN.0.0  price_BIN  991          2018
# 2º Quartil  price_BIN.1.0  price_BIN  973          1557
# NaN         price_BIN.9.0  price_BIN  507          719
# NaN         price_BIN.6.0  price_BIN  813          1185
# 3º Quartil  price_BIN.2.0  price_BIN  896          1271
# NaN         price_BIN.8.0  price_BIN  573          901
# NaN         price_BIN.5.0  price_BIN  837          1164
# NaN         price_BIN.4.0  price_BIN  948          1243
# NaN         price_BIN.7.0  price_BIN  695          997
# 4º Quartil  price_BIN.3.0  price_BIN  939          1363
#
#             true_positive_rate  true_positive_rate_C
# sub
# 1º Quartil  0.270440            0.027400
# 2º Quartil  0.285857            0.028806
# NaN         0.295310            0.041861
# NaN         0.304013            0.031949
# 3º Quartil  0.304748            0.030330
# NaN         0.306002            0.037087
# NaN         0.312398            0.032391
# NaN         0.324986            0.030851
# NaN         0.327449            0.035268
# 4º Quartil  0.340762            0.031013

# %%
df_total.head()
# Out:
#               total_class total_individuals
# sub
# 1º Quartil  991 (12.13 %)  2018 (16.25 %)
# 2º Quartil  973 (11.91 %)  1557 (12.54 %)
# NaN         507 (6.20 %)   719 (5.79 %)
# NaN         813 (9.95 %)   1185 (9.54 %)
# 3º Quartil  896 (10.96 %)  1271 (10.24 %)

# %% [markdown]
# ### All

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_43d5853a51_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'

df_all_metrics    = load_fairness_metrics().loc[input_models_eval]

for input_features in df_all_metrics['sub_key'].unique():
    sub_map = None
    print(input_features)
    fig, df_metrics, df_total = plot_fairness_metrics(input_models_eval, input_features, input_metrics, sub_map = sub_map)    
    #fig.show(renderer="svg")
    fig.write_image("output/tmp/metrics/recsys_fairnes_mistreatment_{}.png".format(input_features.replace("/", "")))
# Out:
# 1 star
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/util.py:21: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# 2 star
# 3 star
# 4 star
# 5 star
# accessible hotel
# accessible parking
# adults only
# air conditioning
# airport hotel
# airport shuttle
# all inclusive (upon inquiry)
# balcony
# bathtub
# beach
# beach bar
# beauty salon
# bed & breakfast
# bike rental
# boat rental
# body treatments
# boutique hotel
# bowling
# bungalows
# business centre
# business hotel
# cable tv
# camping site
# car park
# casa rural (es)
# casino (hotel)
# central heating
# childcare
# club hotel
# computer with internet
# concierge
# conference rooms
# convenience store
# convention hotel
# cosmetic mirror
# cot
# country hotel
# deck chairs
# design hotel
# desk
# direct beach access
# diving
# doctor on-site
# eco-friendly hotel
# electric kettle
# excellent rating
# express check-in / check-out
# family friendly
# fan
# farmstay
# fitness
# flatscreen tv
# free wifi (combined)
# free wifi (public areas)
# free wifi (rooms)
# fridge
# from 2 stars
# from 3 stars
# from 4 stars
# gay-friendly
# golf course
# good rating
# guest house
# gym
# hairdresser
# hairdryer
# halal food
# hammam
# health retreat
# hiking trail
# honeymoon
# horse riding
# hostal (es)
# hostel
# hot stone massage
# hotel
# hotel bar
# house / apartment
# hydrotherapy
# hypoallergenic bedding
# hypoallergenic rooms
# ironing board
# jacuzzi (hotel)
# kids' club
# kosher food
# large groups
# laundry service
# lift
# luxury hotel
# massage
# microwave
# minigolf
# motel
# nightclub
# non-smoking rooms
# on-site boutique shopping
# openable windows
# organised activities
# pet friendly
# playground
# pool table
# porter
# pousada (br)
# radio
# reception (24/7)
# resort
# restaurant
# romantic
# room service
# room service (24/7)
# safe (hotel)
# safe (rooms)
# sailing
# satellite tv
# satisfactory rating
# sauna
# self catering
# senior travellers
# serviced apartment
# shooting sports
# shower
# singles
# sitting area (rooms)
# ski resort
# skiing
# solarium
# spa (wellness facility)
# spa hotel
# star
# steam room
# sun umbrellas
# surfing
# swimming pool (bar)
# swimming pool (combined filter)
# swimming pool (indoor)
# swimming pool (outdoor)
# szep kartya
# table tennis
# telephone
# teleprinter
# television
# tennis court
# tennis court (indoor)
# terrace (hotel)
# theme hotel
# towels
# very good rating
# volleyball
# washing machine
# water slide
# wheelchair accessible
# wifi (public areas)
# wifi (rooms)

# %% [markdown]
# ## Disparate treatment

# %%
def plot_fairness_treatment(df, metric, items, min_count=10, top=False, title="", legend=None):
    data  = []
    i     = 0
    score = 'rhat_scores'



    
    if top:
        # Diff min max score
        df_diff = df.groupby('action').agg(total=(score, 'count'), max_score=(score, 'max'), min_score=(score, 'min'))
        #df_diff['diff'] = df_diff['max_score']-df_diff['min_score']
        items  = df_diff.sort_values('total', ascending=False).index#[:10]
        #items  = [np.random.choice(items) for i in range(100)]


    df    = df.groupby(["action", metric]).agg(
              rewards=("rewards", 'count'),
              metric=(score, 'mean'),
              confidence=(score, confidence)).reset_index()#.sort_values("rhat_scores")

    df    = df[df.rewards > min_count] # filter min interactions
    #df    = df[df.action.isin(items)]

    #------------------
    df_group = df[df['rewards'] > min_count].groupby('action').agg({metric: 'count'}).reset_index()
    df_all   = df_group[df_group[metric] >= 3]['action'].values    

    df       = df[df.action.isin(df_all)].iloc[0:int(3*5)]
    
    
    df3 = df.groupby('action').agg(metric_max=('metric', 'max'), metric_min=('metric', 'min')).reset_index()
    df3['diff'] = df3['metric_max'] - df3['metric_min']

    df = df.merge(df3, on='action').sort_values('diff', ascending=False)
    
    #df_all


    #df    = df[:int(5 * 3)]
    
    for group, rows in df.groupby(metric):
        data.append(go.Bar(name=legend[str(group)], 
                            x=["ID:"+str(a) for a in rows["action"]], 
                            y=rows['metric'],
                            error_y= dict(type='data', array=rows['confidence']) )) #px.colors.sequential.Purp [i for i in range(len(rows))]

        i += 1
    fig = go.Figure(data=data)

    # Change the bar mode
    fig.update_layout(template=TEMPLATE, legend_orientation="h", 
                    yaxis_title=score,
                    legend=dict(y=-0.2), title=title)
    #fig.update_traces(texttemplate='%{y:.2f}', textposition='outside')
    #fig.update_layout(coloraxis = {'colorscale':'Purp'})

    fig.update_layout(shapes=[
      dict(
        type= 'line',
        line=dict(
            width=1,
            dash="dot",
        ),        
        xref='paper', x0= 0, x1= 1,
        yref='y', y0= df['metric'].mean(), y1= df['metric'].mean()
      )
    ])

    st.plotly_chart(fig)
    st.dataframe(df)

    return fig

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'
df_instances      = load_fairness_df().loc[input_models_eval]

input_features    = 'device_idx'
input_metrics     = 'true_positive_rate'
input_items_top = True
input_items     = []
# Out:
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/util.py:21: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
fig = plot_fairness_treatment(df_instances, input_features, input_items, top=input_items_top, 
                          title="",
                          legend={"0.0": "Desktop", "1.0": "Mobile", "2.0": "Tablet"})
fig.update_layout(font={'family': 'Courier New, monospace', 'size': 21}, height=600)



# Set custom x-axis labels
fig.update_yaxes(nticks=5)
fig.update_layout(xaxis_title="Hotel")


fig.show(renderer="svg")
fig.write_image("output/tmp/metrics/paper/recsys_fairnes_impact_{}.eps".format(input_features))
# Out:
# /home/marlesson/anaconda3/envs/deep-reco-gym/lib/python3.6/site-packages/numpy/core/_methods.py:217: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /home/marlesson/anaconda3/envs/deep-reco-gym/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %% [markdown]
# ### Image 2

# %%
input_features    = 'popularity_BIN'

# %%
fig = plot_fairness_treatment(df_instances, input_features, input_items, top=input_items_top, 
                          title="Disparate Treatment - Feature: "+input_features,
                          legend={"0.0": "1º Quartil", "1.0": "2º Quartil", "2.0": "3º Quartil", "3.0": "4º Quartil"})


fig.show(renderer="svg")
fig.write_image("output/tmp/metrics/recsys_fairnes_treatment_{}.eps".format(input_features))

# %% [markdown]
# ### All

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'
df_instances      = load_fairness_df().loc[input_models_eval]
input_metrics     = 'true_positive_rate'
input_items_top = True
input_items     = []

# %%
# def plot_fairness_treatment(df, metric, items, min_count=10, top=False, title="", legend=None):
#     data  = []
#     i     = 0
#     score = 'rhat_scores'

    
#     if top:
#         # Diff min max score
#         df_diff = df.groupby('action').agg(total=(score, 'count'), max_score=(score, 'max'), min_score=(score, 'min'))
#         items  = df_diff.sort_values('total', ascending=False).index[:10]

#     df    = df.groupby(["action", metric]).agg(
#               rewards=("rewards", 'count'),
#               metric=(score, 'mean'),
#               confidence=(score, confidence)).reset_index()#.sort_values("rhat_scores")

#     df    = df[df.rewards > min_count] # filter min interactions

#     #------------------
#     df_group = df[df['rewards'] > min_count].groupby('action').agg({metric: 'count'}).reset_index()

#     df       = df[df.action.isin(items)]#.iloc[0:int(3*10)]
    
    
#     df3 = df.groupby('action').agg(metric_max=('metric', 'max'), metric_min=('metric', 'min')).reset_index()
#     df3['diff'] = df3['metric_max'] - df3['metric_min']

#     df = df.merge(df3, on='action').sort_values('diff', ascending=False)
    
#     for group, rows in df.groupby(metric):
#         data.append(go.Bar(name=str(group), 
#                             x=["Item"+":"+str(a) for a in rows["action"]], 
#                             y=rows['metric'],
#                             error_y= dict(type='data', array=rows['confidence']) )) #px.colors.sequential.Purp [i for i in range(len(rows))]

#         i += 1
#     fig = go.Figure(data=data)

#     # Change the bar mode
#     fig.update_layout(template=TEMPLATE, legend_orientation="h", 
#                     yaxis_title=score,
#                     legend=dict(y=-0.2), title=title)
#     #fig.update_traces(texttemplate='%{y:.2f}', textposition='outside')
#     #fig.update_layout(coloraxis = {'colorscale':'Purp'})

#     fig.update_layout(shapes=[
#       dict(
#         type= 'line',
#         line=dict(
#             width=1,
#             dash="dot",
#         ),        
#         xref='paper', x0= 0, x1= 1,
#         yref='y', y0= df['metric'].mean(), y1= df['metric'].mean()
#       )
#     ])

#     st.plotly_chart(fig)
#     st.dataframe(df)

#     return fig

# df_all_metrics    = load_fairness_metrics().loc[input_models_eval]
# input_features    = 'current_filters_1_star'
# fig = plot_fairness_treatment(df_instances, input_features, input_items, top=input_items_top, 
#                           title="Disparate Impact - Feature: "+input_features)

# fig.show(renderer="svg")
# #if fig != None:
# #    fig.write_image("output/tmp/metrics/recsys_fairnes_impact_{}.png".format(input_features.replace("/", "")))

# %%
input_items_top
# Out:
# True

# %%
# df_all_metrics    = load_fairness_metrics().loc[input_models_eval]

# for input_features in df_all_metrics['sub_key'].unique():
#     sub_map = None
#     print(input_features)
    
    
#     fig = plot_fairness_treatment(df_instances, input_features, input_items, top=input_items_top, 
#                               title="Disparate Impact - Feature: "+input_features)

#     #fig.show(renderer="svg")
#     if fig != None:
#         fig.write_image("output/tmp/metrics/recsys_fairnes_impact_{}.png".format(input_features.replace("/", "")))

# %% [markdown]
# ## Disparate Mistritment

# %%
df_instances.head()
# Out:
#                                                                                                                                        action  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  1868
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  1868
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  1868
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  1868
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  1868
#
#                                                                                                                                        action_type_idx  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
#                                                                                                                                        action_type_item_idx  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
#                                                                                                                                        city_idx  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  8
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  8
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  8
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  8
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  8
#
#                                                                                                                                        clicked  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
#                                                                                                                                        current_filters_1_star  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
#
#                                                                                                                                        current_filters_2_star  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
#
#                                                                                                                                        current_filters_3_star  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
#
#                                                                                                                                        current_filters_4_star  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
#
#                                                                                                                                        current_filters_5_star  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
#
#                                                                                                                                        ...  \
# path                                                                                                                                   ...
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  ...
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  ...
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  ...
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  ...
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  ...
#
#                                                                                                                                        popularity  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
#                                                                                                                                        popularity_BIN  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  2.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  1.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  2.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  2.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  3.0
#
#                                                                                                                                        popularity_item_idx  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
#                                                                                                                                        pos_item_idx  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  5
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  6
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  17
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  5
#
#                                                                                                                                        price  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
#                                                                                                                                        price_BIN  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.0
#
#                                                                                                                                        rewards  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0
#
#                                                                                                                                        rhat_scores  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.971384
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.994982
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.268792
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.146350
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps  0.587561
#
#                                                                                                                                        sum_action_item_before  \
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
#                                                                                                                                        view
# path
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
# TrivagoLogisticModelInteraction_selu____softmax_explorer_400e446a13_68ced32ec3_ps_per_logistic_regression_of_pos_item_idx_and_item_ps NaN
#
# [5 rows x 124 columns]

# %%
df_group = df_instances.groupby('action').agg(total=('rewards', 'count'))#/len(df_instances)
df_group#.plot(kind='bar')
# Out:
#         total
# action
# 5       1
# 6       2
# 7       5
# 8       1
# 11      3
# ...    ..
# 12285   1
# 12299   12
# 12314   1
# 12321   1
# 12328   3
#
# [2379 rows x 1 columns]

# %%
from scipy.stats import norm
ax = sns.distplot(df_group.total, kde=False, bins=100)

# %%
kwargs = {'cumulative': True}
sns.distplot(sorted(df_group.total), hist_kws=kwargs, kde_kws=kwargs, bins=500)
#plt.xlim(0, 0.01)

# %%
df_group.total
# Out:
# action
# 5        0.000081
# 6        0.000161
# 7        0.000403
# 8        0.000081
# 11       0.000242
#            ...
# 12285    0.000081
# 12299    0.000966
# 12314    0.000081
# 12321    0.000081
# 12328    0.000242
# Name: total, Length: 2379, dtype: float64

# %% [markdown]
# ## Disparate Impact

# %%
input_models_eval = 'TrivagoLogisticModelInteraction_selu____softmax_explorer_224970e314_cccf64b73d_ps_per_logistic_regression_of_pos_item_idx_and_item_ps'

df_instances      = load_fairness_df().loc[input_models_eval]

input_features    = 'device_idx'
input_metrics     = 'true_positive_rate'
input_items_top = True
input_items     = []
# Out:
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/util.py:21: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
def plot_fairness_treatment2(df, metric, items, min_count=10, top=False, title="", legend=None):
    data  = []
    i     = 0
    score = 'rhat_scores'

   
    if top:
        # Diff min max score
        df_diff = df.groupby('action').agg(total=(score, 'count'), max_score=(score, 'max'), min_score=(score, 'min'))
        #df_diff['diff'] = df_diff['max_score']-df_diff['min_score']
        items  = df_diff.sort_values('total', ascending=False).index[:10]
        #items  = [np.random.choice(items) for i in range(100)]


    if len(items) > 0:
        df       = df[df.action.isin(items)]#.iloc[0:10]
    #print(df)


    #df    = df[:int(5 * 3)]


    for group, rows in df.groupby(metric):
        data.append(go.Histogram(name=group,
                                x=rows[score], 
                                histnorm='probability density')) #px.colors.sequential.Purp [i for i in range(len(rows))]

        i += 1
        
    
    data.append(go.Histogram(name="All",
                            x=df[score], 
                            histnorm='probability density')) #px.colors.sequential.Purp [i for i in range(len(rows))]
    
            
    fig = go.Figure(data=data)

    # Change the bar mode
    fig.update_layout(template=TEMPLATE, legend_orientation="h", 
                    yaxis_title=score, 
                    legend=dict(y=-0.2), title=title)
    fig.update_layout(barmode='overlay')
    fig.update_traces(opacity=0.75)


    #fig.update_traces(texttemplate='%{y:.2f}', textposition='outside')
    #fig.update_layout(coloraxis = {'colorscale':'Purp'})

#     fig.update_layout(shapes=[
#       dict(
#         type= 'line',
#         line=dict(
#             width=1,
#             dash="dot",
#         ),        
#         xref='paper', x0= 0, x1= 1,
#         yref='y', y0= df['metric'].mean(), y1= df['metric'].mean()
#       )
#     ])

    st.plotly_chart(fig)
    st.dataframe(df)

    return fig


fig = plot_fairness_treatment2(df_instances, input_features, input_items, top=False, 
                          title="Disparate Treatment - Feature: "+input_features,
                          legend={"0": "Desktop", "1": "Mobile", "2": "Tablet"})

#fig.update_layout(barmode='stack')

fig.show(renderer="svg")
#fig.write_image("output/tmp/metrics/recsys_fairnes_treatment_{}.eps".format(input_features))

# %%
import plotly.figure_factory as ff

def plot_fairness_treatment2(df, metric, items, min_count=10, top=False, title="", legend=None):
    data  = []
    i     = 0
    score = 'rhat_scores'

   
    if top:
        # Diff min max score
        df_diff = df.groupby('action').agg(total=(score, 'count'), max_score=(score, 'max'), min_score=(score, 'min'))
        #df_diff['diff'] = df_diff['max_score']-df_diff['min_score']
        items  = df_diff.sort_values('total', ascending=False).index[:10]
        #items  = [np.random.choice(items) for i in range(100)]


    if len(items) > 0:
        df       = df[df.action.isin(items)]#.iloc[0:10]
    #print(df)


    #df    = df[:int(5 * 3)]
    group_labels = []
    
    data.append(df[score])
    group_labels.append("All")   
    
    for group, rows in df.groupby(metric):
        group_labels.append(str(group))
        data.append(rows[score]) 

        i += 1
  
            
    fig = ff.create_distplot(data, group_labels, show_rug=False, show_hist=False)
        
    # Change the bar mode
    fig.update_layout(template=TEMPLATE, legend_orientation="h", 
                    yaxis_title=score, 
                    legend=dict(y=-0.2), title=title)
    #fig.update_layout(barmode='overlay')
    #fig.update_traces(opacity=0.75)


    #fig.update_traces(texttemplate='%{y:.2f}', textposition='outside')
    #fig.update_layout(coloraxis = {'colorscale':'Purp'})

#     fig.update_layout(shapes=[
#       dict(
#         type= 'line',
#         line=dict(
#             width=1,
#             dash="dot",
#         ),        
#         xref='paper', x0= 0, x1= 1,
#         yref='y', y0= df['metric'].mean(), y1= df['metric'].mean()
#       )
#     ])

    st.plotly_chart(fig)
    st.dataframe(df)

    return fig


fig = plot_fairness_treatment2(df_instances, input_features, input_items, top=False, 
                          title="Disparate Treatment - Feature: "+input_features,
                          legend={"0": "Desktop", "1": "Mobile", "2": "Tablet"})

#fig.update_layout(barmode='stack')

fig.show(renderer="svg")
#fig.write_image("output/tmp/metrics/recsys_fairnes_treatment_{}.eps".format(input_features))

# %%
df_all_metrics    = load_fairness_metrics().loc[input_models_eval]

for input_features in df_all_metrics['sub_key'].unique():
    print(input_features)
    
    try:
        fig = plot_fairness_treatment2(df_instances, input_features, input_items, top=False, 
                                      title="Disparate Treatment - Feature: "+input_features)

    #fig.show(renderer="svg")

        fig.write_image("output/tmp/metrics/recsys_fairnes_Treatment_2{}.png".format(input_features.replace("/", "")))    
    except:
        print("Error", input_features)
        pass
