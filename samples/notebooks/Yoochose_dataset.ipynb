# %%
import pandas as pd

# %%
df = pd.read_csv('../../output/yoochoose/dataset/dataset_prepared.csv')
df.head()
# Out:
#    Unnamed: 0  SessionID                         Timestamp     ItemID  Price  \
# 0       20275     466654  2014-04-01 03:21:30.271000+00:00  214584907   4711
# 1       48953     185089  2014-04-01 03:29:09.280000+00:00  214819430    418
# 2       48954     185089  2014-04-01 03:29:09.375000+00:00  214716667    627
# 3       48955     185089  2014-04-01 03:29:09.422000+00:00  214819762    627
# 4       48956     185089  2014-04-01 03:29:09.446000+00:00  214819760    627
#
#    Quantity                                    ItemID_history  Step  \
# 0         1                       ['', '', '', '', 214820812]     2
# 1         1                       ['', '', '', '', 214819376]     2
# 2         1                ['', '', '', 214819376, 214819430]     3
# 3         1         ['', '', 214819376, 214819430, 214716667]     4
# 4         1  ['', 214819376, 214819430, 214716667, 214819762]     5
#
#    Timestamp_dayofweek                                    available_items
# ...

# %%
df = df[["Timestamp", "SessionID", "ItemID", "Step", "Quantity", "ItemID_history", "available_items"]]
df.head()
# Out:
#                           Timestamp  SessionID     ItemID  Step  Quantity  \
# 0  2014-04-01 03:21:30.271000+00:00     466654  214584907     2         1
# 1  2014-04-01 03:29:09.280000+00:00     185089  214819430     2         1
# 2  2014-04-01 03:29:09.375000+00:00     185089  214716667     3         1
# 3  2014-04-01 03:29:09.422000+00:00     185089  214819762     4         1
# 4  2014-04-01 03:29:09.446000+00:00     185089  214819760     5         1
#
#                                      ItemID_history  \
# 0                       ['', '', '', '', 214820812]
# 1                       ['', '', '', '', 214819376]
# 2                ['', '', '', 214819376, 214819430]
# 3         ['', '', 214819376, 214819430, 214716667]
# 4  ['', 214819376, 214819430, 214716667, 214819762]
#
#                                      available_items
# 0  ['214551607', '214850739', '214854791', '21456...
# 1  ['214716971', '214857570', '214853102', '21485...
# ...

# %%
df.to_csv("dataset.csv", index=False)
