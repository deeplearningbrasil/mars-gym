# %%
df = spark.read.parquet("../output/ifood/dataset/ground_truth_Comida Italiana").orderBy("click_timestamp_brt")

# %%
df.limit(100).toPandas()
# Out:
#                              merchant_id  \
# 0   b5a964f4-dc60-41e9-9c3c-e33f8bc89a72
# 1   374d62c7-55f0-4e94-9291-11ab53d7ca91
# 2   2cdc359e-94bf-41bb-b4d9-97411871afb0
# 3   2cdc359e-94bf-41bb-b4d9-97411871afb0
# 4   db503cd0-5563-4f3c-8b66-1bf08f0eb648
# ..                                   ...
# 95  4a4851dd-0d97-4f1d-a97e-1e853726032c
# 96  8949e97a-bbe0-4746-b0da-af6d0cae25e4
# 97  b6131bcf-54a3-4b51-9afe-205defc99828
# 98  36874f2a-1f32-43b2-96b3-9fc75b8ba94e
# 99  b6131bcf-54a3-4b51-9afe-205defc99828
#
#                               account_id              shift  \
# 0   8a36e84d-3c97-4e83-8889-07487051ac9c  weekend breakfast
# 1   fa24eba3-ddba-4d1d-8cd8-eef3645f594b  weekend breakfast
# 2   73011035-40d1-4aa7-8140-b56787231b91  weekend breakfast
# 3   73011035-40d1-4aa7-8140-b56787231b91  weekend breakfast
# 4   28b25e24-8659-4f47-b165-ea7a879e9610  weekend breakfast
# ..                                   ...                ...
# ...

# %%
df.select("merchant_idx").groupBy("merchant_idx").count().show()
# Out:
# +------------+-----+
# |merchant_idx|count|
# +------------+-----+
# |        1339| 1244|
# |         108|    8|
# |         581|  422|
# |         709|   25|
# |         598|   39|
# |          37| 5109|
# |         486|   28|
# |        1216|   42|
# |         834|  148|
# |         537|  601|
# |         445|   33|
# |         247|  670|
# |         524|  599|
# |        1325|   14|
# |        1071|  300|
# |         968|  520|
# |        1221|  161|
# |        1648|   60|
# |        1284|  542|
# |        1014|  822|
# +------------+-----+
# only showing top 20 rows
