# %% [markdown]
# ## Análise de Resultados

# %%
import sys, os
sys.path.insert(0, "/media/workspace/DeepFood/deep-reco-gym/tools/eval_viz")
import pandas as pd
import argparse
import copy
import numpy as np
import os
import random
import json
from pandas.io.json import json_normalize
from app import fetch_iteraction_results_path, load_all_iteraction_metrics, load_iteractions_params
from plot import plot_line_iteraction, plot_exploration_arm, get_colors
import pandas as pd
import argparse
import copy
import numpy as np

import streamlit as st

#sys.path.insert(0, os.path.dirname(__file__))

# %%
models_and_legend = {
  "____random_":           ["bandit_policy", "observation"],
  "____fixed_":            ["bandit_policy", "observation"],
  "____lin_ucb_":          ["bandit_policy", "bandit_policy_params.alpha", "full_refit", "val_split_type"],
  "____model_":            ["bandit_policy","full_refit", "val_split_type"],
  "____custom_lin_ucb_":   ["bandit_policy", "bandit_policy_params.alpha", "full_refit", "val_split_type"],
  "____epsilon_greedy_":   ["bandit_policy","bandit_policy_params.epsilon", "full_refit", "val_split_type"],
  "____softmax_":          ["bandit_policy","bandit_policy_params.logit_multiplier", "full_refit", "val_split_type"],
  "____lin_ts_":           ["bandit_policy","bandit_policy_params.v_sq", "full_refit", "val_split_type"],
  "____percentile_adapt_":       ["bandit_policy","bandit_policy_params.exploration_threshold", "full_refit", "val_split_type"],
  "____adaptive_":         ["bandit_policy","bandit_policy_params.exploration_threshold", "bandit_policy_params.decay_rate", "full_refit", "val_split_type"],  
  "____explore_then_exp_": ["bandit_policy","bandit_policy_params.explore_rounds", "bandit_policy_params.decay_rate", "full_refit", "val_split_type"],    
}

path = "../output/interaction/"

# %%
def list_paths_per_model(input_path):
    models = []
    
    for model, legend in models_and_legend.items():
    #print(model)
    #print(legend)
        for root, dirs, files in os.walk(input_path):
            if '/results' in root and 'Interaction' in root:
                for d in dirs:
                    #print(os.path.join(root, d))
                    if model in d:
                        models.append(os.path.join(root, d))
    return models

# def load_iteractions_params(iteractions):
#     if len(iteractions) == 0:
#         return pd.DataFrame()

#     dfs = []

#     for model in iteractions:

#         file_path = os.path.join(fetch_iteraction_results_path()[model], 'params.json')
#         data      = []

#         try:
#             with open(file_path) as json_file:
#                 d = json.load(json_file)
#                 data.append(d)

#             df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')

#         except:
#             df = pd.DataFrame()

#     df['iteraction'] = model
#     dfs.append(df)

#     return pd.concat(dfs)

def load_iteractions_params(iteractions):
  if len(iteractions) == 0:
    return pd.DataFrame()

  dfs = []

  for model in iteractions:

    file_path = os.path.join(model, 'params.json')
    data      = []

    #try:
    with open(file_path) as json_file:
        d = json.load(json_file)
        data.append(d)

        df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
      
    #except:
    #  df = pd.DataFrame()

    df['iteraction'] = model
    dfs.append(df)
  
  return pd.concat(dfs)


def load_data_iteractions_metrics(path, sample_size = 10000):
    random.seed(42)
    file      = os.path.join(path,'sim-datalog.csv')

    # Count the lines
    num_lines = sum(1 for l in open(file)) - 1

    # Sample size - in this case ~10%
    size = np.min([sample_size, num_lines])#int(num_lines / 10)

    # The row indices to skip - make sure 0 is not included to keep the header!
    skip_idx  = sorted(random.sample(range(1, num_lines), num_lines - size))
    idx       = list(set(list(range(num_lines))) - set(skip_idx))

    df        = pd.read_csv(file, skiprows=skip_idx)
    
    df        = pd.read_csv(file)#.reset_index()
    idx       = list(range(len(df)))

    df['idx'] = sorted(idx)
    df        = df.sort_values("idx")
    return df


def get_metrics_reward(bandits):
    data    = []
    for i, p in enumerate(bandits):
        df_metrics = load_data_iteractions_metrics(p)
        r_mean     = df_metrics.reward.mean()
        r_reward   = df_metrics.reward.sum()
        data.append((i, r_mean, r_reward))
    df_metrics = pd.DataFrame(data, columns=['idx', 'r_mean', 'r_reward']).set_index('idx')    
    return df_metrics

def group_metrics(df):
    df_g_metrics = df.groupby('bandit').agg({'r_mean': ['mean', 'std'], 'r_reward': ['mean', 'std', 'count'] })
    df_g_metrics.columns = df_g_metrics.columns.map(lambda x: '|'.join([str(i) for i in x]))
    return df_g_metrics    
    
result_paths = list_paths_per_model(path)

# %%
df_params = load_iteractions_params(result_paths)
df_params.head()
# Out:
# /home/marlesson/anaconda3/envs/deep-reco-gym/lib/python3.6/site-packages/ipykernel_launcher.py:65: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#   activation_function balance_fields bandit_policy  \
# 0  selu                []             random
# 0  selu                []             fixed
# 0  selu                []             fixed
# 0  selu                []             fixed
# 0  selu                []             lin_ucb
#
#    bandit_policy_params.alpha  bandit_policy_params.arg  \
# 0 NaN                         NaN
# 0 NaN                          2.0
# 0 NaN                          1.0
# 0 NaN                          2.0
# 0  0.01                       NaN
#
#    bandit_policy_params.decay_rate  bandit_policy_params.epsilon  \
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
# 0 NaN                              NaN
#
#    bandit_policy_params.exploration_threshold  \
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
# 0 NaN
#
#    bandit_policy_params.explore_rounds  bandit_policy_params.logit_multiplier  \
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
# 0 NaN                                  NaN
#
#    ...  sampling_strategy  seed session_test_size  split_index test_size  \
# 0  ...  none               42    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.0
# 0  ...  none               42    0.1               0            0.0
# 0  ...  none               1     0.1               0            0.0
# 0  ...  none               3     0.1               0            0.0
#
#   test_split_type use_sampling_in_validation  val_size  val_split_type  \
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
# 0  time            False                      0.2       random
#
#     weight_init
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
# 0  lecun_normal
#
# [5 rows x 54 columns]

# %%
df_params.shape
# Out:
# (96, 54)

# %%
list_bandits = df_params.groupby(["bandit_policy", "observation"])['iteraction'].apply(list).reset_index()
list_bandits['name'] = list_bandits.bandit_policy.map(str) + ' ' + list_bandits.observation.map(str)
list_bandits
# Out:
#            bandit_policy   observation  \
# 0   adaptive
# 1   custom_lin_ucb
# 2   epsilon_greedy
# 3   explore_then_exploit
# 4   fixed                 First Item
# 5   fixed                 Popular Item
# 6   lin_ts
# 7   lin_ucb
# 8   model
# 9   percentile_adaptive
# 10  random
# 11  softmax_explorer
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         iteraction  \
# 0   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_1805a03bf3, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_25eeef1241, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_411d00d36e, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_703f577767, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_77f0fb14c4, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_8b0863a87e, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_c9a2106b16, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_ccda0e5519, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_cf9a362bac, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____adaptive_f3f4bc96ca]
# 1   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_178897b9db, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_2b0e7eda7e, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_3d25f184ae, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_609638d31b, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_73faccd2cb, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_b1a79ad944, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_c6cb5d38da, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_c79f441189, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_eb4f96847c, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____custom_lin_ucb_f825bb29dc]
# 2   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_641e45dd20, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_74363010a4, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_bbf0770e84, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_d72036d12e, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_dc05e1777b, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_f7af9ca04d, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_61b715627f, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_13c548308b, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_388ee3a5c7, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____epsilon_greedy_4af5245f04]
# 3   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_1633d74dc1, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_199ff59574, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_2e53e7c4ca, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_5e94099c87, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_663a7bbf25, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_d917b2d738, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_e3f73695bd, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_f8d04850a4, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_fdcea1acbf, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____explore_then_exp_fe55b53c7f]
# 4   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_c755e18c94]
# 5   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_603f5e460c, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____fixed_f55477c050]
# 6   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_bb817340ab, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_bf8d6e3013, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_eaea041825, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_ed1bfeb917, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_59156c9103, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_04eb6cf7c3, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_07dcfd7ee6, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_124eb7f027, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_135989dfb3, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ts_45f3ebb7db]
# 7   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_126cf72bae, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_20bf3e4540, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_3f02c73d45, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_7933c50c19, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_8ea1839e25, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_92954ab323, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_a9548f6842, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_b3de80fdbb, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_bbfd008b63, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_f6d1497043, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____lin_ucb_ff1b161dc5]
# 8   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_8cbc96dfb2, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_bdbdd590e8, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_cbab1c0468, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_f36d4f34c2, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_033f8a5517, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_0bf89768ed, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_34add2987e, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_4ad32002c3, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_6607f61d4b, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_68d3f84ab5, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____model_6c2160cc22]
# 9   [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_eb3cf98eaf, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_39ef79c68a, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_5d6eb0c381, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_8fcae9c6cc, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_a55b1fc341, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_c7776ae540, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_ccaf433ffc, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_d1e0355df6, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_d944a5ac49, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____percentile_adapt_db6f110398]
# 10  [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____random_88b2d0895d]
# 11  [../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_0733edca2b, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_0a373f9939, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_0e6632a956, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_263e33cfbe, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_6102bd0e7c, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_8fcee14ca6, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_92b3f51df7, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_bddb12caec, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_d2cf166e2e, ../output/interaction/TrivagoLogisticModelInteraction/results/TrivagoLogisticModelInteraction_selu____softmax_explorer_e02033d44c]
#
#                      name
# 0   adaptive
# 1   custom_lin_ucb
# 2   epsilon_greedy
# 3   explore_then_exploit
# 4   fixed First Item
# 5   fixed Popular Item
# 6   lin_ts
# 7   lin_ucb
# 8   model
# 9   percentile_adaptive
# 10  random
# 11  softmax_explorer

# %% [markdown]
# ## Geral

# %%
reward_metrics = []

# %%
for i, row in list_bandits.iterrows():
    df_metrics = get_metrics_reward(row['iteraction'])
    df_metrics['bandit'] = row['name']
    
    df_g_metrics = group_metrics(df_metrics)
    reward_metrics.append(df_g_metrics)

# %%
df_all = pd.concat(reward_metrics)
df_all
# Out:
#                        r_mean|mean  r_mean|std  r_reward|mean  r_reward|std  \
# bandit
# adaptive               0.234012     0.010587    3092.700000    139.914299
# custom_lin_ucb         0.086441     0.005248    1142.400000    69.364096
# epsilon_greedy         0.209973     0.009722    2775.000000    128.482597
# explore_then_exploit   0.213983     0.007338    2828.000000    96.983389
# fixed First Item       0.255826    NaN          3381.000000   NaN
# fixed Popular Item     0.099297     0.001103    1107.000000    275.771645
# lin_ts                 0.045097     0.001944    596.000000     25.694790
# lin_ucb                0.064573     0.011692    781.909091     74.426413
# model                  0.298407     0.087725    3899.818182    1303.056009
# percentile_adaptive    0.261183     0.008483    3451.800000    112.107885
# random                 0.042222    NaN          558.000000    NaN
# softmax_explorer       0.259617     0.013882    3431.100000    183.462046
#
#                        r_reward|count
# bandit
# adaptive               10
# custom_lin_ucb         10
# epsilon_greedy         10
# explore_then_exploit   10
# fixed First Item       1
# fixed Popular Item     2
# lin_ts                 10
# lin_ucb                11
# model                  11
# percentile_adaptive    10
# random                 1
# softmax_explorer       10

# %%
df_all[['r_reward|mean', 'r_reward|std']].plot(kind='bar')

# %% [markdown]
# ## Plot

# %%
sys.path.insert(0, "/media/workspace/DeepFood/deep-reco-gym")

input_legend      = ['bandit_policy']
input_iteraction  = [p.split("/")[-1] for p in result_paths]
sample_size       = 1000

st.set_option("client.displayEnabled", False)

metrics           = load_all_iteraction_metrics(input_iteraction, sample_size)
params            = load_iteractions_params(input_iteraction)

df_metrics_reward = metrics.groupby("iteraction").agg({'reward': ['mean', 'sum']}).reset_index().sort_values([('reward', 'sum')], ascending=False)

df  = metrics.merge(params, on=['iteraction'], how='left')\
            .merge(metrics.groupby("iteraction")\
                    .agg({'reward': 'mean'})\
                    .rename(columns={'reward': 'sum_reward'})\
                    .reset_index(), 
              on=['iteraction'], how='left')\
            .reset_index()\
            .sort_values(['sum_reward', 'idx'], ascending=[False, True])

print(df.head())
print(params.head())
print(df_metrics_reward)

# GERAL
#for input_metrics in ['Cumulative Reward', 'Cumulative Mean Reward', 'Cumulative Window Mean Reward']:
input_metrics = 'Cumulative Mean Reward'
fig = plot_line_iteraction(df, 'reward', 
                      title=input_metrics, 
                      legend=input_legend,
                      line_dict=get_colors(input_iteraction),
                      yrange=[0,1], 
                      window=args.window_size,
                      cum=(input_metrics == 'Cumulative Reward'), 
                      mean=(input_metrics == 'Cumulative Mean Reward'),
                      roll=(input_metrics == 'Cumulative Window Mean Reward'))

fig
#fig.write_image(args.output+"/all_{}.png".format(input_metrics.replace(" ", ""))) #, width=1024, height=600, scale=2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-29937113190e> in <module>
#       7 st.set_option("client.displayEnabled", False)
#       8
# ----> 9 metrics           = load_all_iteraction_metrics(input_iteraction, sample_size)
#      10 params            = load_iteractions_params(input_iteraction)
#      11
#
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/app.py in load_all_iteraction_metrics(iteractions, sample_size)
#     210   for iteraction in iteractions:
#     211     #try:
# --> 212     metric = load_data_iteractions_metrics(iteraction, sample_size)
#     213     #except:
#     214     #  continue
#
# /media/workspace/DeepFood/deep-reco-gym/tools/eval_viz/app.py in load_data_iteractions_metrics(model, sample_size)
#     173 def load_data_iteractions_metrics(model, sample_size = 10000):
#     174   random.seed(42)
# --> 175   file      = os.path.join(fetch_iteraction_results_path()[model],'sim-datalog.csv')
#     176
#     177   # Count the lines
#
# KeyError: 'TrivagoLogisticModelInteraction_selu____random_88b2d0895d'

# %%
fetch_iteraction_results_path()
# Out:
# {}

# %%
os.walk(PATH_EVAL_REINFORCEMENT, followlinks=True)
