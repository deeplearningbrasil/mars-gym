# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = "https://musicbrainz.org/artist/"

# %%
df = pd.read_csv("/home/marlesson/workspace/DeepFood/recommendation-system/output/lastfm/dataset/artist_id_indices.csv")
df.sample(100).head(50)
# Out:
#         artist_idx                             artist_id
# 100218      100218  4e871dff-df89-45f5-857f-28067cdc9d5e
# 71705        71705  b163fe11-0c4a-40e1-980e-0422770cb814
# 96911        96911  f518869c-5ac3-4f32-9a61-4b49f8eba625
# 40131        40131  96bcdacc-59bc-41b5-ac66-18e5b55f1689
# 11326        11326  1ef82ba1-8b47-485c-8706-f5fa81c70fe7
# 95407        95407  e27aa3d6-6a49-4a1b-8fb0-4593356e62d3
# 25887        25887  36a5ee70-6183-4dc6-a946-2034bfc57d66
# 19558        19558  f6501458-e99e-4d63-9141-b32eb70fd5ec
# 70049        70049  6f8c42b6-1fd2-450d-8cb7-f7516ea624ba
# 75662        75662  a7fcc0f1-ff65-44bc-99e3-cf4c3e983283
# 25635        25635  6973d8cb-2356-43a6-b2dc-eca79d7ba4f6
# 47831        47831  3bc7fff6-8466-4d6f-a04f-b5964660455e
# 83662        83662  bae69e18-b0ff-4659-8a76-7ceb341ae8e3
# 97938        97938  1607f199-e5c0-4eb7-8b28-d5a3bd8fdea2
# 33672        33672  f150ed27-bee7-49d8-a226-31fef88c29b3
# ...

# %%
df.shape
# Out:
# (107398, 2)

# %%
id = "3ef4bd40-6157-450e-88f2-f2a7f83e0f06"#df.iloc[1].artist_id

page = requests.get(url+id)

# Criar o objeto BeautifulSoup
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
